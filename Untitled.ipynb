# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Задание 2

# %%
print(1/2 + 1/3 + 1/6) # на бумаге это равно 1
# Out:
# 0.9999999999999999

# %%
print(1/2+1/3+1/18+1/12+1/36) # для 6ти дробей
# Out:
# 1.0
